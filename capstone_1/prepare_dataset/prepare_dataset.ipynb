# %%
import os
import shutil

# %%
SOURCE_DIR = "SUNRGBD"
OUTPUT_DIR = "dataset"
SPLITTED_OUTPUT_DIR = "splitted_dataset"

# %%
VALID_CLASSES = {
    "bedroom": "bedroom",
    "bathroom": "bathroom",
    "kitchen": "kitchen",
    "living_room": "living_room"
}

# %%
os.makedirs(OUTPUT_DIR, exist_ok=True)

for root, dirs, files in os.walk(SOURCE_DIR):
    if "scene.txt" in files:
        scene_path = os.path.join(root, "scene.txt")

        with open(scene_path, "r") as f:
            label = f.read().strip().lower()

        if label not in VALID_CLASSES:
            continue

        image_dir = os.path.join(root, "image")
        if not os.path.exists(image_dir):
            continue

        images = os.listdir(image_dir)
        if len(images) == 0:
            continue

        img_path = os.path.join(image_dir, images[0])

        out_dir = os.path.join(OUTPUT_DIR, label)
        os.makedirs(out_dir, exist_ok=True)

        new_name = f"{os.path.basename(root)}.jpg"
        shutil.copy(img_path, os.path.join(out_dir, new_name))

# %%
from PIL import Image

# %%
def clean_corrupted_images(folder):
    for root, _, files in os.walk(folder):
        for f in files:
            path = os.path.join(root, f)
            try:
                img = Image.open(path)
                img.verify()
            except Exception as error:
                print(error)
                print("Removing:", path)
                os.remove(path)

clean_corrupted_images(OUTPUT_DIR)
clean_corrupted_images(SPLITTED_OUTPUT_DIR)
# Out:
# cannot identify image file 'splitted_dataset/test/.DS_Store'
# Removing: splitted_dataset/test/.DS_Store

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/miniconda3/envs/ml-zoomcamp/lib/python3.11/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /opt/miniconda3/envs/ml-zoomcamp/lib/python3.11/site-packages (from opencv-python) (2.0.1)

# %%
import cv2
import numpy as np
import os

def is_too_dark(img_path, threshold=25):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    return img.mean() < threshold

for cls in os.listdir(OUTPUT_DIR):
    cls_path = f"dataset/{cls}"
    for img in os.listdir(cls_path):
        img_path = os.path.join(cls_path, img)
        if is_too_dark(img_path):
            os.remove(img_path)
            print("Removing:", img_path)
# Out:
# Removing: dataset/bedroom/NYU1040.jpg
# Removing: dataset/bedroom/0001540-000051594771.jpg
# Removing: dataset/bedroom/NYU1149.jpg
# Removing: dataset/bedroom/0001020-000034163159.jpg
# Removing: dataset/bedroom/0000485-000016286857.jpg
# Removing: dataset/bathroom/0000956-000032017365.jpg
# Removing: dataset/bathroom/0000496-000016600005.jpg
# Removing: dataset/living_room/NYU0603.jpg
# Removing: dataset/living_room/0001252-000085021004.jpg
# Removing: dataset/living_room/NYU0154.jpg
# Removing: dataset/kitchen/0005957-001031848999.jpg

# %%
import imagehash

# %%
# !pip install imagehash
# Out:
# Requirement already satisfied: imagehash in /opt/miniconda3/envs/ml-zoomcamp/lib/python3.11/site-packages (4.3.2)
# Requirement already satisfied: PyWavelets in /opt/miniconda3/envs/ml-zoomcamp/lib/python3.11/site-packages (from imagehash) (1.9.0)
# Requirement already satisfied: numpy in /opt/miniconda3/envs/ml-zoomcamp/lib/python3.11/site-packages (from imagehash) (2.0.1)
# Requirement already satisfied: pillow in /opt/miniconda3/envs/ml-zoomcamp/lib/python3.11/site-packages (from imagehash) (11.3.0)
# Requirement already satisfied: scipy in /opt/miniconda3/envs/ml-zoomcamp/lib/python3.11/site-packages (from imagehash) (1.16.1)

# %%
import imagehash

# %%
hashes = {}
for cls in os.listdir(OUTPUT_DIR):
    for img in os.listdir(f"{OUTPUT_DIR}/{cls}"):
        path = f"{OUTPUT_DIR}/{cls}/{img}"
        h = imagehash.phash(Image.open(path))
        if h in hashes:
            os.remove(path)
            print("Removing:", path)
        else:
            hashes[h] = path

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders

splitfolders.ratio(
    OUTPUT_DIR,
    output=SPLITTED_OUTPUT_DIR,
    seed=42,
    ratio=(0.7, 0.2, 0.1)
)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./loan_data.csv')
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# 1                   0                   OWN     1000.0          EDUCATION
# 2                   3              MORTGAGE     5500.0            MEDICAL
# 3                   0                  RENT    35000.0            MEDICAL
# 4                   1                  RENT    35000.0            MEDICAL
# ...               ...                   ...        ...                ...
# 44995               6                  RENT    15000.0            MEDICAL
# 44996              17                  RENT     9000.0    HOMEIMPROVEMENT
# 44997               7                  RENT     2771.0  DEBTCONSOLIDATION
# 44998               4                  RENT    12000.0          EDUCATION
# 44999               1                  RENT     6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 1              11.14                 0.08                         2.0
# 2              12.87                 0.44                         3.0
# 3              15.23                 0.44                         2.0
# 4              14.27                 0.53                         4.0
# ...              ...                  ...                         ...
# 44995          15.66                 0.31                         3.0
# 44996          14.07                 0.14                        11.0
# 44997          10.02                 0.05                        10.0
# 44998          13.23                 0.36                         6.0
# 44999          17.05                 0.13                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 1               504                            Yes            0
# 2               635                             No            1
# 3               675                             No            1
# 4               586                             No            1
# ...             ...                            ...          ...
# 44995           645                             No            1
# 44996           621                             No            1
# 44997           668                             No            1
# 44998           604                             No            1
# 44999           628                             No            1
#
# [45000 rows x 14 columns]

# %%
numerical = ["person_age", "person_income", "person_emp_exp", "loan_amnt", "loan_int_rate", "loan_percent_income", "cb_person_cred_hist_length", "credit_score"]
categorical = ["person_gender", "person_education", "person_home_ownership", "loan_intent", "previous_loan_defaults_on_file"]

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# 25%         8.590000             0.070000                    3.000000
# 50%        11.010000             0.120000                    4.000000
# 75%        12.990000             0.190000                    8.000000
# max        20.000000             0.660000                   30.000000
#
#        credit_score   loan_status
# count  45000.000000  45000.000000
# mean     632.608756      0.222222
# std       50.435865      0.415744
# min      390.000000      0.000000
# 25%      601.000000      0.000000
# 50%      640.000000      0.000000
# 75%      670.000000      0.000000
# max      850.000000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
#  12  previous_loan_defaults_on_file  45000 non-null  object
#  13  loan_status                     45000 non-null  int64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 4.8+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for col in numerical:
    plt.figure(figsize=(6, 4))
    
    sns.histplot(df[col], bins=50, color='black', alpha=1)
    
    plt.ticklabel_format(style='plain', axis='both')
    
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    
    plt.show()

# %%
df = df[df['person_age'] < 72]

# %%
df = df[df['person_income'] < 1000000]

# %%
df['previous_loan_defaults_on_file'] = df['previous_loan_defaults_on_file'].replace(['No', 'Yes'], [0, 1]).astype(int)
# Out:
# /var/folders/pd/fx9stk756697jx8_ft4b76080000gp/T/ipykernel_92222/2712561509.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['previous_loan_defaults_on_file'] = df['previous_loan_defaults_on_file'].replace(['No', 'Yes'], [0, 1]).astype(int)

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df.describe()
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# count    44964.00       44964.00        44964.00   44964.00       44964.00
# mean        27.73       79249.61            5.38    9582.32          11.01
# std          5.86       54687.52            5.87    6313.69           2.98
# min         20.00        8000.00            0.00     500.00           5.42
# 25%         24.00       47170.75            1.00    5000.00           8.59
# 50%         26.00       67040.00            4.00    8000.00          11.01
# 75%         30.00       95703.25            8.00   12237.25          13.00
# max         70.00      994605.00           50.00   35000.00          20.00
#
#        loan_percent_income  cb_person_cred_hist_length  credit_score  \
# count             44964.00                    44964.00      44964.00
# mean                  0.14                        5.86        632.57
# std                   0.09                        3.86         50.39
# min                   0.00                        2.00        390.00
# 25%                   0.07                        3.00        601.00
# 50%                   0.12                        4.00        640.00
# 75%                   0.19                        8.00        670.00
# max                   0.66                       30.00        784.00
#
#        previous_loan_defaults_on_file  loan_status
# count                        44964.00     44964.00
# mean                             0.51         0.22
# std                              0.50         0.42
# min                              0.00         0.00
# 25%                              0.00         0.00
# 50%                              1.00         0.00
# 75%                              1.00         0.00
# max                              1.00         1.00

# %%
pd.reset_option('display.float_format')

# %%
df = df.reset_index(drop=True)

# %%
numerical = ["person_age", "person_income", "person_emp_exp", "loan_amnt", "loan_int_rate", "loan_percent_income", "cb_person_cred_hist_length", "credit_score", "previous_loan_defaults_on_file"]
categorical = ["person_gender", "person_education", "person_home_ownership", "loan_intent"]

# %%
correlation_matrix = df[numerical].corr()

# %%
plt.figure(figsize=(5, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  44964.000000   44964.000000    44964.000000  44964.000000
# mean      27.731741   79249.610088        5.377658   9582.322658
# std        5.858240   54687.524297        5.873644   6313.689027
# min       20.000000    8000.000000        0.000000    500.000000
# 25%       24.000000   47170.750000        1.000000   5000.000000
# 50%       26.000000   67040.000000        4.000000   8000.000000
# 75%       30.000000   95703.250000        8.000000  12237.250000
# max       70.000000  994605.000000       50.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   44964.000000         44964.000000                44964.000000
# mean       11.006872             0.139803                    5.858487
# std         2.979364             0.087185                    3.862217
# min         5.420000             0.000000                    2.000000
# 25%         8.590000             0.070000                    3.000000
# 50%        11.010000             0.120000                    4.000000
# 75%        13.000000             0.190000                    8.000000
# max        20.000000             0.660000                   30.000000
#
#        credit_score  previous_loan_defaults_on_file   loan_status
# count  44964.000000                    44964.000000  44964.000000
# mean     632.568855                        0.507917      0.222400
# std       50.390799                        0.499943      0.415863
# min      390.000000                        0.000000      0.000000
# 25%      601.000000                        0.000000      0.000000
# 50%      640.000000                        1.000000      0.000000
# 75%      670.000000                        1.000000      0.000000
# max      784.000000                        1.000000      1.000000

# %%
from sklearn.model_selection import train_test_split

# %%
df_train_full, df_test = train_test_split(df, test_size=0.2, random_state=21)

# %%
df_train, df_val = train_test_split(df_train_full, test_size=0.25, random_state=21)

# %%
df_train
# Out:
#        person_age person_gender person_education  person_income  \
# 26470        28.0          male           Master       124557.0
# 43356        23.0          male         Bachelor        71091.0
# 15475        24.0          male         Bachelor       154488.0
# 13199        23.0          male           Master       109071.0
# 19698        28.0          male      High School        70259.0
# ...           ...           ...              ...            ...
# 18035        34.0          male        Associate        90727.0
# 16206        21.0          male         Bachelor        74552.0
# 12670        26.0        female         Bachelor        75903.0
# 6700         22.0          male           Master        61072.0
# 6034         26.0          male        Associate        64317.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 26470               4              MORTGAGE    10000.0            VENTURE
# 43356               0                  RENT    19979.0  DEBTCONSOLIDATION
# 15475               0              MORTGAGE    18000.0  DEBTCONSOLIDATION
# 13199               0              MORTGAGE     3000.0           PERSONAL
# 19698               4                  RENT     3300.0           PERSONAL
# ...               ...                   ...        ...                ...
# 18035               9                  RENT    25000.0  DEBTCONSOLIDATION
# 16206               1              MORTGAGE     4000.0    HOMEIMPROVEMENT
# 12670               7                  RENT    12000.0            VENTURE
# 6700                0              MORTGAGE     8000.0           PERSONAL
# 6034                0                  RENT     5700.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 26470           7.51                 0.08                        10.0
# 43356          12.83                 0.28                         3.0
# 15475          17.27                 0.12                         2.0
# 13199           6.03                 0.03                         4.0
# 19698          11.01                 0.05                         8.0
# ...              ...                  ...                         ...
# 18035          10.38                 0.28                         8.0
# 16206          11.01                 0.05                         2.0
# 12670          12.23                 0.16                         4.0
# 6700           11.12                 0.13                         3.0
# 6034           11.12                 0.09                         2.0
#
#        credit_score  previous_loan_defaults_on_file  loan_status
# 26470           578                               1            0
# 43356           590                               0            1
# 15475           691                               0            1
# 13199           661                               0            0
# 19698           682                               1            0
# ...             ...                             ...          ...
# 18035           576                               0            1
# 16206           659                               0            1
# 12670           520                               1            0
# 6700            679                               1            0
# 6034            658                               1            0
#
# [26978 rows x 14 columns]

# %%
y_train = df_train.loan_status.values
y_val = df_val.loan_status.values
y_train_full = df_train_full.loan_status.values
y_test = df_test.loan_status.values

# %%
del df_train['loan_status']
del df_val['loan_status']
del df_train_full['loan_status']
del df_test['loan_status']

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, f1_score, roc_auc_score

# %%
def train_model_and_get_metrics(df_train, y_train, df_val, y_val, features_list, c, class_weight='balanced'):
    print(f"Training final model on full train set with C={c}")

    # Train on training data
    train_dict = df_train[features_list].to_dict(orient='records')
    dv_train = DictVectorizer(sparse=False)
    dv_train.fit(train_dict)
    X_train = dv_train.transform(train_dict)
    
    # Train model on training set
    model_final = LogisticRegression(solver='liblinear', C=c, max_iter=1000, random_state=21, class_weight=class_weight)
    model_final.fit(X_train, y_train)
    
    # Evaluate on TEST set
    val_dict = df_val[features_list].to_dict(orient='records')
    X_val = dv_train.transform(val_dict)
    y_pred_val = model_final.predict_proba(X_val)[:, 1]

    # Try different thresholds
    thresholds = np.linspace(0.1, 0.8, 81)  # Test 81 thresholds from 0.1 to 0.9
    f1_scores = []
    
    for threshold in thresholds:
        y_pred = (y_pred_val >= threshold).astype(int)
        f1 = f1_score(y_val, y_pred)
        f1_scores.append(f1)
    
    # Find best threshold
    best_idx = np.argmax(f1_scores)
    best_threshold = thresholds[best_idx]
    best_f1 = f1_scores[best_idx]
    
    # Apply best threshold
    y_pred_val_final = (y_pred_val >= best_threshold).astype(int)
    
    # Calculate final TEST metrics
    print(f"\nBest treshold: {best_threshold:.4f}")
    print(f"\nBest F1 Score: {f1_score(y_val, y_pred_val_final):.4f}")
    print(f"Test Set ROC-AUC Score: {roc_auc_score(y_val, y_pred_val):.4f}")
    print("\nTest Set Classification Report:")
    print(classification_report(y_val, y_pred_val_final))
    return model_final

# %%
def train_model_and_get_metrics_dynamic(df_train, y_train, df_val, y_val, features_list, 
                                c_values=None, class_weight='balanced', 
                                optimize_for='f1'):
    if c_values is None:
        c_values = [0.001, 0.01, 0.1, 1, 10, 100]
    
    print(f"Searching for best C from {c_values}")
    print(f"Optimizing for: {optimize_for}")
    
    # Prepare training data
    train_dict = df_train[features_list].to_dict(orient='records')
    dv_train = DictVectorizer(sparse=False)
    dv_train.fit(train_dict)
    X_train = dv_train.transform(train_dict)
    
    # Prepare validation data
    val_dict = df_val[features_list].to_dict(orient='records')
    X_val = dv_train.transform(val_dict)
    
    # Find best C
    best_c = None
    best_score = -1
    best_threshold = 0.5
    results = []
    
    for c in c_values:
        # Train model
        model = LogisticRegression(solver='liblinear', C=c, max_iter=1000, 
                                  random_state=21, class_weight=class_weight)
        model.fit(X_train, y_train)
        
        # Get predictions
        y_pred_proba = model.predict_proba(X_val)[:, 1]
        
        if optimize_for == 'f1':
            # Find best threshold for F1
            thresholds = np.linspace(0.1, 0.8, 81)
            f1_scores = []
            
            for threshold in thresholds:
                y_pred = (y_pred_proba >= threshold).astype(int)
                f1 = f1_score(y_val, y_pred)
                f1_scores.append(f1)
            
            best_idx = np.argmax(f1_scores)
            threshold = thresholds[best_idx]
            score = f1_scores[best_idx]
        else:  # roc_auc
            score = roc_auc_score(y_val, y_pred_proba)
            threshold = 0.5
        
        results.append({'C': c, 'score': score, 'threshold': threshold})
        print(f"C={c:7.4f} | {optimize_for.upper()}={score:.4f} | threshold={threshold:.4f}")
        
        if score > best_score:
            best_score = score
            best_c = c
            best_threshold = threshold
    
    # Train final model with best C
    print(f"\n{'='*60}")
    print(f"Best C: {best_c}")
    print(f"Best {optimize_for.upper()}: {best_score:.4f}")
    print(f"Best threshold: {best_threshold:.4f}")
    print(f"{'='*60}\n")
    
    model_final = LogisticRegression(solver='liblinear', C=best_c, max_iter=1000, 
                                    random_state=21, class_weight=class_weight)
    model_final.fit(X_train, y_train)
    
    # Final evaluation
    y_pred_proba = model_final.predict_proba(X_val)[:, 1]
    y_pred_final = (y_pred_proba >= best_threshold).astype(int)
    
    print(f"Final Model Performance:")
    print(f"F1 Score: {f1_score(y_val, y_pred_final):.4f}")
    print(f"ROC-AUC Score: {roc_auc_score(y_val, y_pred_proba):.4f}")
    print("\nClassification Report:")
    print(classification_report(y_val, y_pred_final))
    
    return model_final, dv_train, best_threshold

# %%
numerical_for_regression = ["person_age", "person_income", "loan_amnt", "loan_int_rate", "loan_percent_income", "credit_score", "previous_loan_defaults_on_file"]
#numerical_for_regression = ["person_emp_exp", "person_income", "loan_amnt", "loan_int_rate", "loan_percent_income", "credit_score", "previous_loan_defaults_on_file"]
#numerical_for_regression = ["cb_person_cred_hist_length", "person_income", "loan_amnt", "loan_int_rate", "loan_percent_income", "credit_score", "previous_loan_defaults_on_file"]

# %%
all_features = categorical + numerical
all_features
# Out:
# ['person_gender',
#  'person_education',
#  'person_home_ownership',
#  'loan_intent',
#  'person_age',
#  'person_income',
#  'person_emp_exp',
#  'loan_amnt',
#  'loan_int_rate',
#  'loan_percent_income',
#  'cb_person_cred_hist_length',
#  'credit_score',
#  'previous_loan_defaults_on_file']

# %%
all_features = categorical + numerical
all_features_for_regression = categorical + numerical_for_regression
train_model_and_get_metrics_dynamic(df_train, y_train, df_val, y_val, all_features, class_weight='balanced')
# Out:
# Searching for best C from [0.001, 0.01, 0.1, 1, 10, 100]
# Optimizing for: f1
# C= 0.0010 | F1=0.7417 | threshold=0.6075
# C= 0.0100 | F1=0.7541 | threshold=0.6512
# C= 0.1000 | F1=0.7506 | threshold=0.6338
# C= 1.0000 | F1=0.7543 | threshold=0.6512
# C=10.0000 | F1=0.7501 | threshold=0.6338
# C=100.0000 | F1=0.7500 | threshold=0.6338
#
# ============================================================
# Best C: 1
# Best F1: 0.7543
# Best threshold: 0.6512
# ============================================================
#
# Final Model Performance:
# F1 Score: 0.7543
# ROC-AUC Score: 0.9444
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      6916
#            1       0.68      0.84      0.75      2077
#
#     accuracy                           0.87      8993
#    macro avg       0.82      0.86      0.83      8993
# weighted avg       0.89      0.87      0.88      8993
# (LogisticRegression(C=1, class_weight='balanced', max_iter=1000, random_state=21,
#                     solver='liblinear'),
#  DictVectorizer(sparse=False),
#  np.float64(0.65125))

# %%
train_model_and_get_metrics_dynamic(df_train, y_train, df_val, y_val, all_features, class_weight=None)
# Out:
# Searching for best C from [0.001, 0.01, 0.1, 1, 10, 100]
# Optimizing for: f1
# C= 0.0010 | F1=0.6550 | threshold=0.3275
# C= 0.0100 | F1=0.6522 | threshold=0.3275
# C= 0.1000 | F1=0.6509 | threshold=0.3363
# C= 1.0000 | F1=0.6512 | threshold=0.3363
# C=10.0000 | F1=0.6512 | threshold=0.3363
# C=100.0000 | F1=0.6010 | threshold=0.3100
#
# ============================================================
# Best C: 0.001
# Best F1: 0.6550
# Best threshold: 0.3275
# ============================================================
#
# Final Model Performance:
# F1 Score: 0.6550
# ROC-AUC Score: 0.8589
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      6916
#            1       0.62      0.70      0.66      2077
#
#     accuracy                           0.83      8993
#    macro avg       0.76      0.78      0.77      8993
# weighted avg       0.84      0.83      0.83      8993
# (LogisticRegression(C=0.001, max_iter=1000, random_state=21, solver='liblinear'),
#  DictVectorizer(sparse=False),
#  np.float64(0.3275))

# %%
train_model_and_get_metrics_dynamic(df_train, y_train, df_val, y_val, all_features_for_regression, class_weight='balanced')
# Out:
# Searching for best C from [0.001, 0.01, 0.1, 1, 10, 100]
# Optimizing for: f1
# C= 0.0010 | F1=0.7327 | threshold=0.6075
# C= 0.0100 | F1=0.7515 | threshold=0.6075
# C= 0.1000 | F1=0.7524 | threshold=0.6250
# C= 1.0000 | F1=0.7524 | threshold=0.6075
# C=10.0000 | F1=0.7524 | threshold=0.6075
# C=100.0000 | F1=0.7524 | threshold=0.6338
#
# ============================================================
# Best C: 0.1
# Best F1: 0.7524
# Best threshold: 0.6250
# ============================================================
#
# Final Model Performance:
# F1 Score: 0.7524
# ROC-AUC Score: 0.9432
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      6916
#            1       0.67      0.85      0.75      2077
#
#     accuracy                           0.87      8993
#    macro avg       0.81      0.86      0.83      8993
# weighted avg       0.89      0.87      0.88      8993
# (LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000,
#                     random_state=21, solver='liblinear'),
#  DictVectorizer(sparse=False),
#  np.float64(0.625))

# %%
train_model_and_get_metrics_dynamic(df_train, y_train, df_val, y_val, all_features_for_regression, class_weight=None)
# Out:
# Searching for best C from [0.001, 0.01, 0.1, 1, 10, 100]
# Optimizing for: f1
# C= 0.0010 | F1=0.6801 | threshold=0.3450
# C= 0.0100 | F1=0.7273 | threshold=0.3713
# C= 0.1000 | F1=0.6746 | threshold=0.3713
# C= 1.0000 | F1=0.7477 | threshold=0.3800
# C=10.0000 | F1=0.7469 | threshold=0.3713
# C=100.0000 | F1=0.7459 | threshold=0.3800
#
# ============================================================
# Best C: 1
# Best F1: 0.7477
# Best threshold: 0.3800
# ============================================================
#
# Final Model Performance:
# F1 Score: 0.7477
# ROC-AUC Score: 0.9159
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93      6916
#            1       0.76      0.73      0.75      2077
#
#     accuracy                           0.89      8993
#    macro avg       0.84      0.83      0.84      8993
# weighted avg       0.88      0.89      0.88      8993
# (LogisticRegression(C=1, max_iter=1000, random_state=21, solver='liblinear'),
#  DictVectorizer(sparse=False),
#  np.float64(0.38))

# %%
def train_model_and_get_metrics(df_train, y_train, df_val, y_val, features_list, 
                                c_values=None, class_weights=None, 
                                optimize_for='f1'):
    if c_values is None:
        c_values = [0.001, 0.01, 0.1, 1, 10, 100]
    
    if class_weights is None:
        class_weights = [None, 'balanced']
    
    print(f"Searching for best C from {c_values}")
    print(f"Searching for best class_weight from {class_weights}")
    print(f"Optimizing for: {optimize_for}")
    print(f"Total combinations to test: {len(c_values) * len(class_weights)}\n")
    
    # Prepare training data
    train_dict = df_train[features_list].to_dict(orient='records')
    dv_train = DictVectorizer(sparse=False)
    dv_train.fit(train_dict)
    X_train = dv_train.transform(train_dict)
    
    # Prepare validation data
    val_dict = df_val[features_list].to_dict(orient='records')
    X_val = dv_train.transform(val_dict)
    
    # Find best combination of C and class_weight
    best_c = None
    best_class_weight = None
    best_score = -1
    best_threshold = 0.5
    results = []
    
    for class_weight in class_weights:
        for c in c_values:
            # Train model
            model = LogisticRegression(solver='liblinear', C=c, max_iter=1000, 
                                      random_state=21, class_weight=class_weight)
            model.fit(X_train, y_train)
            
            # Get predictions
            y_pred_proba = model.predict_proba(X_val)[:, 1]
            
            if optimize_for == 'f1':
                # Find best threshold for F1
                thresholds = np.linspace(0.1, 0.8, 81)
                f1_scores = []
                
                for threshold in thresholds:
                    y_pred = (y_pred_proba >= threshold).astype(int)
                    f1 = f1_score(y_val, y_pred)
                    f1_scores.append(f1)
                
                best_idx = np.argmax(f1_scores)
                threshold = thresholds[best_idx]
                score = f1_scores[best_idx]
            else:  # roc_auc
                score = roc_auc_score(y_val, y_pred_proba)
                threshold = 0.5
            
            results.append({
                'C': c, 
                'class_weight': class_weight, 
                'score': score, 
                'threshold': threshold
            })
            
            cw_str = str(class_weight).ljust(10)
            print(f"class_weight={cw_str} | C={c:7.4f} | {optimize_for.upper()}={score:.4f} | threshold={threshold:.4f}")
            
            if score > best_score:
                best_score = score
                best_c = c
                best_class_weight = class_weight
                best_threshold = threshold
    
    # Train final model with best parameters
    print(f"\n{'='*60}")
    print(f"Best class_weight: {best_class_weight}")
    print(f"Best C: {best_c}")
    print(f"Best {optimize_for.upper()}: {best_score:.4f}")
    print(f"Best threshold: {best_threshold:.4f}")
    print(f"{'='*60}\n")
    
    model_final = LogisticRegression(solver='liblinear', C=best_c, max_iter=1000, 
                                    random_state=21, class_weight=best_class_weight)
    model_final.fit(X_train, y_train)
    
    # Final evaluation
    y_pred_proba = model_final.predict_proba(X_val)[:, 1]
    y_pred_final = (y_pred_proba >= best_threshold).astype(int)
    
    print(f"Final Model Performance:")
    print(f"F1 Score: {f1_score(y_val, y_pred_final):.4f}")
    print(f"ROC-AUC Score: {roc_auc_score(y_val, y_pred_proba):.4f}")
    print("\nClassification Report:")
    print(classification_report(y_val, y_pred_final))
    
    return model_final, dv_train, best_threshold

# %%
log_regression_model, log_regression_dv, log_regression_threshold = train_model_and_get_metrics(df_train, y_train, df_val, y_val, all_features)
# Out:
# Searching for best C from [0.001, 0.01, 0.1, 1, 10, 100]
# Searching for best class_weight from [None, 'balanced']
# Optimizing for: f1
# Total combinations to test: 12
#
# class_weight=None       | C= 0.0010 | F1=0.6550 | threshold=0.3275
# class_weight=None       | C= 0.0100 | F1=0.6522 | threshold=0.3275
# class_weight=None       | C= 0.1000 | F1=0.6509 | threshold=0.3363
# class_weight=None       | C= 1.0000 | F1=0.6512 | threshold=0.3363
# class_weight=None       | C=10.0000 | F1=0.6512 | threshold=0.3363
# class_weight=None       | C=100.0000 | F1=0.6010 | threshold=0.3100
# class_weight=balanced   | C= 0.0010 | F1=0.7417 | threshold=0.6075
# class_weight=balanced   | C= 0.0100 | F1=0.7541 | threshold=0.6512
# class_weight=balanced   | C= 0.1000 | F1=0.7506 | threshold=0.6338
# class_weight=balanced   | C= 1.0000 | F1=0.7543 | threshold=0.6512
# class_weight=balanced   | C=10.0000 | F1=0.7501 | threshold=0.6338
# class_weight=balanced   | C=100.0000 | F1=0.7500 | threshold=0.6338
#
# ============================================================
# Best class_weight: balanced
# Best C: 1
# Best F1: 0.7543
# Best threshold: 0.6512
# ============================================================
#
# Final Model Performance:
# F1 Score: 0.7543
# ROC-AUC Score: 0.9444
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      6916
#            1       0.68      0.84      0.75      2077
#
#     accuracy                           0.87      8993
#    macro avg       0.82      0.86      0.83      8993
# weighted avg       0.89      0.87      0.88      8993

# %%
train_model_and_get_metrics(df_train, y_train, df_val, y_val, all_features_for_regression)
# Out:
# Searching for best C from [0.001, 0.01, 0.1, 1, 10, 100]
# Searching for best class_weight from [None, 'balanced']
# Optimizing for: f1
# Total combinations to test: 12
#
# class_weight=None       | C= 0.0010 | F1=0.6801 | threshold=0.3450
# class_weight=None       | C= 0.0100 | F1=0.7273 | threshold=0.3713
# class_weight=None       | C= 0.1000 | F1=0.6746 | threshold=0.3713
# class_weight=None       | C= 1.0000 | F1=0.7477 | threshold=0.3800
# class_weight=None       | C=10.0000 | F1=0.7469 | threshold=0.3713
# class_weight=None       | C=100.0000 | F1=0.7459 | threshold=0.3800
# class_weight=balanced   | C= 0.0010 | F1=0.7327 | threshold=0.6075
# class_weight=balanced   | C= 0.0100 | F1=0.7515 | threshold=0.6075
# class_weight=balanced   | C= 0.1000 | F1=0.7524 | threshold=0.6250
# class_weight=balanced   | C= 1.0000 | F1=0.7524 | threshold=0.6075
# class_weight=balanced   | C=10.0000 | F1=0.7524 | threshold=0.6075
# class_weight=balanced   | C=100.0000 | F1=0.7524 | threshold=0.6338
#
# ============================================================
# Best class_weight: balanced
# Best C: 0.1
# Best F1: 0.7524
# Best threshold: 0.6250
# ============================================================
#
# Final Model Performance:
# F1 Score: 0.7524
# ROC-AUC Score: 0.9432
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      6916
#            1       0.67      0.85      0.75      2077
#
#     accuracy                           0.87      8993
#    macro avg       0.81      0.86      0.83      8993
# weighted avg       0.89      0.87      0.88      8993
# (LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000,
#                     random_state=21, solver='liblinear'),
#  DictVectorizer(sparse=False),
#  np.float64(0.625))

# %%
train_model_and_get_metrics(df_train, y_train, df_val, y_val, all_features_for_regression, optimize_for='roc_auc')
# Out:
# Searching for best C from [0.001, 0.01, 0.1, 1, 10, 100]
# Searching for best class_weight from [None, 'balanced']
# Optimizing for: roc_auc
# Total combinations to test: 12
#
# class_weight=None       | C= 0.0010 | ROC_AUC=0.8759 | threshold=0.5000
# class_weight=None       | C= 0.0100 | ROC_AUC=0.9090 | threshold=0.5000
# class_weight=None       | C= 0.1000 | ROC_AUC=0.8755 | threshold=0.5000
# class_weight=None       | C= 1.0000 | ROC_AUC=0.9159 | threshold=0.5000
# class_weight=None       | C=10.0000 | ROC_AUC=0.9166 | threshold=0.5000
# class_weight=None       | C=100.0000 | ROC_AUC=0.9154 | threshold=0.5000
# class_weight=balanced   | C= 0.0010 | ROC_AUC=0.9195 | threshold=0.5000
# class_weight=balanced   | C= 0.0100 | ROC_AUC=0.9428 | threshold=0.5000
# class_weight=balanced   | C= 0.1000 | ROC_AUC=0.9432 | threshold=0.5000
# class_weight=balanced   | C= 1.0000 | ROC_AUC=0.9436 | threshold=0.5000
# class_weight=balanced   | C=10.0000 | ROC_AUC=0.9436 | threshold=0.5000
# class_weight=balanced   | C=100.0000 | ROC_AUC=0.9432 | threshold=0.5000
#
# ============================================================
# Best class_weight: balanced
# Best C: 1
# Best ROC_AUC: 0.9436
# Best threshold: 0.5000
# ============================================================
#
# Final Model Performance:
# F1 Score: 0.7265
# ROC-AUC Score: 0.9436
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.81      0.89      6916
#            1       0.60      0.92      0.73      2077
#
#     accuracy                           0.84      8993
#    macro avg       0.79      0.87      0.81      8993
# weighted avg       0.89      0.84      0.85      8993
# (LogisticRegression(C=1, class_weight='balanced', max_iter=1000, random_state=21,
#                     solver='liblinear'),
#  DictVectorizer(sparse=False),
#  0.5)

# %%
train_model_and_get_metrics(df_train_full, y_train_full, df_test, y_test, all_features_for_regression)
# Out:
# Searching for best C from [0.001, 0.01, 0.1, 1, 10, 100]
# Searching for best class_weight from [None, 'balanced']
# Optimizing for: f1
# Total combinations to test: 12
#
# class_weight=None       | C= 0.0010 | F1=0.5325 | threshold=0.3363
# class_weight=None       | C= 0.0100 | F1=0.5325 | threshold=0.3363
# class_weight=None       | C= 0.1000 | F1=0.5325 | threshold=0.3363
# class_weight=None       | C= 1.0000 | F1=0.5325 | threshold=0.3363
# class_weight=None       | C=10.0000 | F1=0.5325 | threshold=0.3363
# class_weight=None       | C=100.0000 | F1=0.5325 | threshold=0.3363
# class_weight=balanced   | C= 0.0010 | F1=0.7290 | threshold=0.5988
# class_weight=balanced   | C= 0.0100 | F1=0.7290 | threshold=0.6338
# class_weight=balanced   | C= 0.1000 | F1=0.7322 | threshold=0.5988
# class_weight=balanced   | C= 1.0000 | F1=0.7334 | threshold=0.6163
# class_weight=balanced   | C=10.0000 | F1=0.7302 | threshold=0.6512
# class_weight=balanced   | C=100.0000 | F1=0.7334 | threshold=0.6075
#
# ============================================================
# Best class_weight: balanced
# Best C: 100
# Best F1: 0.7334
# Best threshold: 0.6075
# ============================================================
#
# Final Model Performance:
# F1 Score: 0.7334
# ROC-AUC Score: 0.9418
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91      7029
#            1       0.63      0.87      0.73      1964
#
#     accuracy                           0.86      8993
#    macro avg       0.80      0.87      0.82      8993
# weighted avg       0.89      0.86      0.87      8993
# (LogisticRegression(C=100, class_weight='balanced', max_iter=1000,
#                     random_state=21, solver='liblinear'),
#  DictVectorizer(sparse=False),
#  np.float64(0.6075))

# %%
train_model_and_get_metrics(df_train_full, y_train_full, df_test, y_test, all_features_for_regression, optimize_for='roc_auc')
# Out:
# Searching for best C from [0.001, 0.01, 0.1, 1, 10, 100]
# Searching for best class_weight from [None, 'balanced']
# Optimizing for: roc_auc
# Total combinations to test: 12
#
# class_weight=None       | C= 0.0010 | ROC_AUC=0.7612 | threshold=0.5000
# class_weight=None       | C= 0.0100 | ROC_AUC=0.7612 | threshold=0.5000
# class_weight=None       | C= 0.1000 | ROC_AUC=0.7612 | threshold=0.5000
# class_weight=None       | C= 1.0000 | ROC_AUC=0.7612 | threshold=0.5000
# class_weight=None       | C=10.0000 | ROC_AUC=0.7612 | threshold=0.5000
# class_weight=None       | C=100.0000 | ROC_AUC=0.7612 | threshold=0.5000
# class_weight=balanced   | C= 0.0010 | ROC_AUC=0.9288 | threshold=0.5000
# class_weight=balanced   | C= 0.0100 | ROC_AUC=0.9352 | threshold=0.5000
# class_weight=balanced   | C= 0.1000 | ROC_AUC=0.9414 | threshold=0.5000
# class_weight=balanced   | C= 1.0000 | ROC_AUC=0.9416 | threshold=0.5000
# class_weight=balanced   | C=10.0000 | ROC_AUC=0.9368 | threshold=0.5000
# class_weight=balanced   | C=100.0000 | ROC_AUC=0.9418 | threshold=0.5000
#
# ============================================================
# Best class_weight: balanced
# Best C: 100
# Best ROC_AUC: 0.9418
# Best threshold: 0.5000
# ============================================================
#
# Final Model Performance:
# F1 Score: 0.7120
# ROC-AUC Score: 0.9418
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.81      0.89      7029
#            1       0.58      0.93      0.71      1964
#
#     accuracy                           0.84      8993
#    macro avg       0.78      0.87      0.80      8993
# weighted avg       0.89      0.84      0.85      8993
# (LogisticRegression(C=100, class_weight='balanced', max_iter=1000,
#                     random_state=21, solver='liblinear'),
#  DictVectorizer(sparse=False),
#  0.5)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
def train_random_forest_and_get_metrics(df_train, y_train, df_val, y_val, features_list,
                                       n_estimators_values=None, max_depth_values=None,
                                       min_samples_split_values=None, min_samples_leaf_values=None,
                                       max_features_values=None, class_weights=None,
                                       optimize_for='f1', n_jobs=-1):
    if n_estimators_values is None:
        n_estimators_values = [50, 100, 200]
    if max_depth_values is None:
        max_depth_values = [3, 5, 10, 15, None]
    if min_samples_split_values is None:
        min_samples_split_values = [2, 5, 10]
    if min_samples_leaf_values is None:
        min_samples_leaf_values = [1, 2, 4]
    if max_features_values is None:
        max_features_values = ['sqrt', 'log2', None]
    if class_weights is None:
        class_weights = [None, 'balanced']
    
    total_combinations = (len(n_estimators_values) * len(max_depth_values) * 
                         len(min_samples_split_values) * len(min_samples_leaf_values) *
                         len(max_features_values) * len(class_weights))
    
    print(f"Random Forest Hyperparameter Search")
    print(f"{'='*70}")
    print(f"n_estimators: {n_estimators_values}")
    print(f"max_depth: {max_depth_values}")
    print(f"min_samples_split: {min_samples_split_values}")
    print(f"min_samples_leaf: {min_samples_leaf_values}")
    print(f"max_features: {max_features_values}")
    print(f"class_weight: {class_weights}")
    print(f"Optimizing for: {optimize_for}")
    print(f"Total combinations to test: {total_combinations}")
    print(f"Note: This may take a while...\n")
    
    # Prepare training data
    train_dict = df_train[features_list].to_dict(orient='records')
    dv_train = DictVectorizer(sparse=False)
    dv_train.fit(train_dict)
    X_train = dv_train.transform(train_dict)
    
    # Prepare validation data
    val_dict = df_val[features_list].to_dict(orient='records')
    X_val = dv_train.transform(val_dict)
    
    # Grid search
    best_params = {}
    best_score = -1
    best_threshold = 0.5
    results = []
    iteration = 0
    
    for class_weight in class_weights:
        for n_estimators in n_estimators_values:
            for max_depth in max_depth_values:
                for min_samples_split in min_samples_split_values:
                    for min_samples_leaf in min_samples_leaf_values:
                        for max_features in max_features_values:
                            iteration += 1
                            
                            # Train model
                            model = RandomForestClassifier(
                                n_estimators=n_estimators,
                                max_depth=max_depth,
                                min_samples_split=min_samples_split,
                                min_samples_leaf=min_samples_leaf,
                                max_features=max_features,
                                class_weight=class_weight,
                                random_state=21,
                                n_jobs=n_jobs
                            )
                            model.fit(X_train, y_train)
                            
                            # Get predictions
                            y_pred_proba = model.predict_proba(X_val)[:, 1]
                            
                            if optimize_for == 'f1':
                                # Find best threshold for F1
                                thresholds = np.linspace(0.1, 0.8, 81)
                                f1_scores = [f1_score(y_val, (y_pred_proba >= t).astype(int)) 
                                            for t in thresholds]
                                best_idx = np.argmax(f1_scores)
                                threshold = thresholds[best_idx]
                                score = f1_scores[best_idx]
                            else:  # roc_auc
                                score = roc_auc_score(y_val, y_pred_proba)
                                threshold = 0.5
                            
                            results.append({
                                'n_estimators': n_estimators,
                                'max_depth': max_depth,
                                'min_samples_split': min_samples_split,
                                'min_samples_leaf': min_samples_leaf,
                                'max_features': max_features,
                                'class_weight': class_weight,
                                'score': score,
                                'threshold': threshold
                            })
                            
                            if iteration % 10 == 0:
                                print(f"Progress: {iteration}/{total_combinations} combinations tested...")
                            
                            if score > best_score:
                                best_score = score
                                best_threshold = threshold
                                best_params = {
                                    'n_estimators': n_estimators,
                                    'max_depth': max_depth,
                                    'min_samples_split': min_samples_split,
                                    'min_samples_leaf': min_samples_leaf,
                                    'max_features': max_features,
                                    'class_weight': class_weight
                                }
                                print(f"  New best score: {best_score:.4f} with params: {best_params}")
    
    # Train final model with best parameters
    print(f"\n{'='*70}")
    print(f"Best Parameters:")
    for param, value in best_params.items():
        print(f"  {param}: {value}")
    print(f"Best {optimize_for.upper()}: {best_score:.4f}")
    print(f"Best threshold: {best_threshold:.4f}")
    print(f"{'='*70}\n")
    
    model_final = RandomForestClassifier(
        n_estimators=best_params['n_estimators'],
        max_depth=best_params['max_depth'],
        min_samples_split=best_params['min_samples_split'],
        min_samples_leaf=best_params['min_samples_leaf'],
        max_features=best_params['max_features'],
        class_weight=best_params['class_weight'],
        random_state=21,
        n_jobs=n_jobs
    )
    model_final.fit(X_train, y_train)
    
    # Final evaluation
    y_pred_proba = model_final.predict_proba(X_val)[:, 1]
    y_pred_final = (y_pred_proba >= best_threshold).astype(int)
    
    print(f"Final Model Performance:")
    print(f"F1 Score: {f1_score(y_val, y_pred_final):.4f}")
    print(f"ROC-AUC Score: {roc_auc_score(y_val, y_pred_proba):.4f}")
    print("\nClassification Report:")
    print(classification_report(y_val, y_pred_final))
    
    return model_final, dv_train, best_threshold

# %%
random_forest_model, random_forest_dv, random_forest_threshold = train_random_forest_and_get_metrics(df_train, y_train, df_val, y_val, all_features)
# Out:
# Random Forest Hyperparameter Search
# ======================================================================
# n_estimators: [50, 100, 200]
# max_depth: [3, 5, 10, 15, None]
# min_samples_split: [2, 5, 10]
# min_samples_leaf: [1, 2, 4]
# max_features: ['sqrt', 'log2', None]
# class_weight: [None, 'balanced']
# Optimizing for: f1
# Total combinations to test: 810
# Note: This may take a while...
#
#   New best score: 0.7871 with params: {'n_estimators': 50, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': None}
#   New best score: 0.7903 with params: {'n_estimators': 50, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'class_weight': None}
# Progress: 10/810 combinations tested...
# Progress: 20/810 combinations tested...
#   New best score: 0.8072 with params: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': None}
# Progress: 30/810 combinations tested...
#   New best score: 0.8081 with params: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'class_weight': None}
# Progress: 40/810 combinations tested...
#   New best score: 0.8086 with params: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': None}
#   New best score: 0.8093 with params: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'class_weight': None}
# Progress: 50/810 combinations tested...
#   New best score: 0.8223 with params: {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': None}
#   New best score: 0.8298 with params: {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'class_weight': None}
# Progress: 60/810 combinations tested...
# Progress: 70/810 combinations tested...
# Progress: 80/810 combinations tested...
#   New best score: 0.8303 with params: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'class_weight': None}
#   New best score: 0.8319 with params: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'class_weight': None}
#   New best score: 0.8325 with params: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': None}
# Progress: 90/810 combinations tested...
# Progress: 100/810 combinations tested...
#   New best score: 0.8335 with params: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': None}
#   New best score: 0.8340 with params: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None, 'class_weight': None}
# Progress: 110/810 combinations tested...
# Progress: 120/810 combinations tested...
# Progress: 130/810 combinations tested...
# Progress: 140/810 combinations tested...
# Progress: 150/810 combinations tested...
# Progress: 160/810 combinations tested...
# Progress: 170/810 combinations tested...
# Progress: 180/810 combinations tested...
# Progress: 190/810 combinations tested...
# Progress: 200/810 combinations tested...
# Progress: 210/810 combinations tested...
#   New best score: 0.8343 with params: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'class_weight': None}
# Progress: 220/810 combinations tested...
#   New best score: 0.8352 with params: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': None}
# Progress: 230/810 combinations tested...
#   New best score: 0.8352 with params: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': None}
# Progress: 240/810 combinations tested...
# Progress: 250/810 combinations tested...
# Progress: 260/810 combinations tested...
# Progress: 270/810 combinations tested...
# Progress: 280/810 combinations tested...
# Progress: 290/810 combinations tested...
# Progress: 300/810 combinations tested...
# Progress: 310/810 combinations tested...
# Progress: 320/810 combinations tested...
# Progress: 330/810 combinations tested...
# Progress: 340/810 combinations tested...
# Progress: 350/810 combinations tested...
# Progress: 360/810 combinations tested...
# Progress: 370/810 combinations tested...
# Progress: 380/810 combinations tested...
#   New best score: 0.8367 with params: {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': None}
# Progress: 390/810 combinations tested...
# Progress: 400/810 combinations tested...
# Progress: 410/810 combinations tested...
# Progress: 420/810 combinations tested...
# Progress: 430/810 combinations tested...
# Progress: 440/810 combinations tested...
# Progress: 450/810 combinations tested...
# Progress: 460/810 combinations tested...
# Progress: 470/810 combinations tested...
# Progress: 480/810 combinations tested...
# Progress: 490/810 combinations tested...
# Progress: 500/810 combinations tested...
# Progress: 510/810 combinations tested...
# Progress: 520/810 combinations tested...
# Progress: 530/810 combinations tested...
# Progress: 540/810 combinations tested...
# Progress: 550/810 combinations tested...
# Progress: 560/810 combinations tested...
# Progress: 570/810 combinations tested...
# Progress: 580/810 combinations tested...
# Progress: 590/810 combinations tested...
# Progress: 600/810 combinations tested...
# Progress: 610/810 combinations tested...
# Progress: 620/810 combinations tested...
# Progress: 630/810 combinations tested...
# Progress: 640/810 combinations tested...
# Progress: 650/810 combinations tested...
# Progress: 660/810 combinations tested...
# Progress: 670/810 combinations tested...
# Progress: 680/810 combinations tested...
# Progress: 690/810 combinations tested...
# Progress: 700/810 combinations tested...
# Progress: 710/810 combinations tested...
# Progress: 720/810 combinations tested...
# Progress: 730/810 combinations tested...
# Progress: 740/810 combinations tested...
# Progress: 750/810 combinations tested...
# Progress: 760/810 combinations tested...
# Progress: 770/810 combinations tested...
# Progress: 780/810 combinations tested...
# Progress: 790/810 combinations tested...
# Progress: 800/810 combinations tested...
# Progress: 810/810 combinations tested...
#
# ======================================================================
# Best Parameters:
#   n_estimators: 200
#   max_depth: None
#   min_samples_split: 2
#   min_samples_leaf: 2
#   max_features: None
#   class_weight: None
# Best F1: 0.8367
# Best threshold: 0.4325
# ======================================================================
#
# Final Model Performance:
# F1 Score: 0.8367
# ROC-AUC Score: 0.9737
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      6916
#            1       0.86      0.81      0.84      2077
#
#     accuracy                           0.93      8993
#    macro avg       0.90      0.89      0.89      8993
# weighted avg       0.93      0.93      0.93      8993

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
def train_decision_tree_and_get_metrics(df_train, y_train, df_val, y_val, features_list,
                                       max_depth_values=None, min_samples_split_values=None,
                                       min_samples_leaf_values=None, class_weights=None,
                                       optimize_for='f1'):
    
    if max_depth_values is None:
        max_depth_values = [2, 3, 5, 7, 10, 12, 15, None]
    if min_samples_split_values is None:
        min_samples_split_values = [2, 5, 7, 10]
    if min_samples_leaf_values is None:
        min_samples_leaf_values = [1, 2, 4]
    if class_weights is None:
        class_weights = [None, 'balanced']
    
    total_combinations = (len(max_depth_values) * len(min_samples_split_values) * 
                         len(min_samples_leaf_values) * len(class_weights))
    
    print(f"Decision Tree Hyperparameter Search")
    print(f"{'='*70}")
    print(f"max_depth: {max_depth_values}")
    print(f"min_samples_split: {min_samples_split_values}")
    print(f"min_samples_leaf: {min_samples_leaf_values}")
    print(f"class_weight: {class_weights}")
    print(f"Optimizing for: {optimize_for}")
    print(f"Total combinations to test: {total_combinations}\n")
    
    # Prepare training data
    train_dict = df_train[features_list].to_dict(orient='records')
    dv_train = DictVectorizer(sparse=False)
    dv_train.fit(train_dict)
    X_train = dv_train.transform(train_dict)
    
    # Prepare validation data
    val_dict = df_val[features_list].to_dict(orient='records')
    X_val = dv_train.transform(val_dict)
    
    # Grid search
    best_params = {}
    best_score = -1
    best_threshold = 0.5
    results = []
    
    for class_weight in class_weights:
        for max_depth in max_depth_values:
            for min_samples_split in min_samples_split_values:
                for min_samples_leaf in min_samples_leaf_values:
                    # Train model
                    model = DecisionTreeClassifier(
                        max_depth=max_depth,
                        min_samples_split=min_samples_split,
                        min_samples_leaf=min_samples_leaf,
                        class_weight=class_weight,
                        random_state=21
                    )
                    model.fit(X_train, y_train)
                    
                    # Get predictions
                    y_pred_proba = model.predict_proba(X_val)[:, 1]
                    
                    if optimize_for == 'f1':
                        # Find best threshold for F1
                        thresholds = np.linspace(0.1, 0.8, 81)
                        f1_scores = [f1_score(y_val, (y_pred_proba >= t).astype(int)) 
                                    for t in thresholds]
                        best_idx = np.argmax(f1_scores)
                        threshold = thresholds[best_idx]
                        score = f1_scores[best_idx]
                    else:  # roc_auc
                        score = roc_auc_score(y_val, y_pred_proba)
                        threshold = 0.5
                    
                    results.append({
                        'max_depth': max_depth,
                        'min_samples_split': min_samples_split,
                        'min_samples_leaf': min_samples_leaf,
                        'class_weight': class_weight,
                        'score': score,
                        'threshold': threshold
                    })
                    
                    if score > best_score:
                        best_score = score
                        best_threshold = threshold
                        best_params = {
                            'max_depth': max_depth,
                            'min_samples_split': min_samples_split,
                            'min_samples_leaf': min_samples_leaf,
                            'class_weight': class_weight
                        }
    
    # Train final model with best parameters
    print(f"\n{'='*70}")
    print(f"Best Parameters:")
    for param, value in best_params.items():
        print(f"  {param}: {value}")
    print(f"Best {optimize_for.upper()}: {best_score:.4f}")
    print(f"Best threshold: {best_threshold:.4f}")
    print(f"{'='*70}\n")
    
    model_final = DecisionTreeClassifier(
        max_depth=best_params['max_depth'],
        min_samples_split=best_params['min_samples_split'],
        min_samples_leaf=best_params['min_samples_leaf'],
        class_weight=best_params['class_weight'],
        random_state=21
    )
    model_final.fit(X_train, y_train)
    
    # Final evaluation
    y_pred_proba = model_final.predict_proba(X_val)[:, 1]
    y_pred_final = (y_pred_proba >= best_threshold).astype(int)
    
    print(f"Final Model Performance:")
    print(f"F1 Score: {f1_score(y_val, y_pred_final):.4f}")
    print(f"ROC-AUC Score: {roc_auc_score(y_val, y_pred_proba):.4f}")
    print("\nClassification Report:")
    print(classification_report(y_val, y_pred_final))
    
    return model_final, dv_train, best_threshold

# %%
decision_tree_model, decision_tree_dv, decision_tree_treshold = train_decision_tree_and_get_metrics(df_train, y_train, df_val, y_val, all_features)
# Out:
# Decision Tree Hyperparameter Search
# ======================================================================
# max_depth: [2, 3, 5, 7, 10, 12, 15, None]
# min_samples_split: [2, 5, 7, 10]
# min_samples_leaf: [1, 2, 4]
# class_weight: [None, 'balanced']
# Optimizing for: f1
# Total combinations to test: 192
#
#
# ======================================================================
# Best Parameters:
#   max_depth: 10
#   min_samples_split: 5
#   min_samples_leaf: 1
#   class_weight: balanced
# Best F1: 0.8140
# Best threshold: 0.7125
# ======================================================================
#
# Final Model Performance:
# F1 Score: 0.8140
# ROC-AUC Score: 0.9605
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      6916
#            1       0.88      0.76      0.81      2077
#
#     accuracy                           0.92      8993
#    macro avg       0.90      0.86      0.88      8993
# weighted avg       0.92      0.92      0.92      8993

# %%
X_test = decision_tree_dv.transform(df_test.to_dict(orient='records'))
y_test_pred_proba = decision_tree_model.predict_proba(X_test)[:, 1]
y_pred_final = (y_test_pred_proba >= decision_tree_treshold).astype(int)

# %%
print(f"F1 Score: {f1_score(y_test, y_pred_final):.4f}")
print(f"ROC-AUC Score: {roc_auc_score(y_test, y_test_pred_proba):.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_final))
# Out:
# F1 Score: 0.8037
# ROC-AUC Score: 0.9581
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      7029
#            1       0.86      0.75      0.80      1964
#
#     accuracy                           0.92      8993
#    macro avg       0.90      0.86      0.88      8993
# weighted avg       0.92      0.92      0.92      8993

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred_final)
# Out:
# 0.9197153341487824

# %%
X_test = random_forest_dv.transform(df_test.to_dict(orient='records'))
y_test_pred_proba = random_forest_model.predict_proba(X_test)[:, 1]
y_pred_final = (y_test_pred_proba >= random_forest_threshold).astype(int)

# %%
print(f"F1 Score: {f1_score(y_test, y_pred_final):.4f}")
print(f"ROC-AUC Score: {roc_auc_score(y_test, y_test_pred_proba):.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_final))
# Out:
# F1 Score: 0.8292
# ROC-AUC Score: 0.9750
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      7029
#            1       0.85      0.81      0.83      1964
#
#     accuracy                           0.93      8993
#    macro avg       0.90      0.89      0.89      8993
# weighted avg       0.93      0.93      0.93      8993

# %%
accuracy_score(y_test, y_pred_final)
# Out:
# 0.9268319804292228

# %%
X_test = log_regression_dv.transform(df_test.to_dict(orient='records'))
y_test_pred_proba = log_regression_model.predict_proba(X_test)[:, 1]
y_pred_final = (y_test_pred_proba >= log_regression_threshold).astype(int)

# %%
print(f"F1 Score: {f1_score(y_test, y_pred_final):.4f}")
print(f"ROC-AUC Score: {roc_auc_score(y_test, y_test_pred_proba):.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_final))
# Out:
# F1 Score: 0.7352
# ROC-AUC Score: 0.9433
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91      7029
#            1       0.65      0.84      0.74      1964
#
#     accuracy                           0.87      8993
#    macro avg       0.80      0.86      0.82      8993
# weighted avg       0.89      0.87      0.87      8993

# %%
accuracy_score(y_test, y_pred_final)
# Out:
# 0.8674524630267986

# %% [markdown]
# Final model training

# %%
random_forest_model, random_forest_dv, random_forest_threshold = train_random_forest_and_get_metrics(df_train_full, y_train_full, df_test, y_test, all_features)
# Out:
# Random Forest Hyperparameter Search
# ======================================================================
# n_estimators: [50, 100, 200]
# max_depth: [3, 5, 10, 15, None]
# min_samples_split: [2, 5, 10]
# min_samples_leaf: [1, 2, 4]
# max_features: ['sqrt', 'log2', None]
# class_weight: [None, 'balanced']
# Optimizing for: f1
# Total combinations to test: 810
# Note: This may take a while...
#
#   New best score: 0.7757 with params: {'n_estimators': 50, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': None}
#   New best score: 0.7876 with params: {'n_estimators': 50, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'class_weight': None}
# Progress: 10/810 combinations tested...
# Progress: 20/810 combinations tested...
#   New best score: 0.8057 with params: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': None}
# Progress: 30/810 combinations tested...
#   New best score: 0.8078 with params: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'class_weight': None}
# Progress: 40/810 combinations tested...
# Progress: 50/810 combinations tested...
#   New best score: 0.8174 with params: {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': None}
#   New best score: 0.8217 with params: {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'class_weight': None}
# Progress: 60/810 combinations tested...
#   New best score: 0.8243 with params: {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': None}
# Progress: 70/810 combinations tested...
# Progress: 80/810 combinations tested...
#   New best score: 0.8287 with params: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': None}
#   New best score: 0.8301 with params: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'class_weight': None}
#   New best score: 0.8321 with params: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': None}
# Progress: 90/810 combinations tested...
#   New best score: 0.8323 with params: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'class_weight': None}
# Progress: 100/810 combinations tested...
#   New best score: 0.8323 with params: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None, 'class_weight': None}
# Progress: 110/810 combinations tested...
#   New best score: 0.8340 with params: {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'class_weight': None}
#   New best score: 0.8340 with params: {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'class_weight': None}
#   New best score: 0.8358 with params: {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': None}
# Progress: 120/810 combinations tested...
# Progress: 130/810 combinations tested...
# Progress: 140/810 combinations tested...
# Progress: 150/810 combinations tested...
# Progress: 160/810 combinations tested...
# Progress: 170/810 combinations tested...
# Progress: 180/810 combinations tested...
# Progress: 190/810 combinations tested...
# Progress: 200/810 combinations tested...
# Progress: 210/810 combinations tested...
# Progress: 220/810 combinations tested...
# Progress: 230/810 combinations tested...
# Progress: 240/810 combinations tested...
#   New best score: 0.8365 with params: {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': None}
# Progress: 250/810 combinations tested...
# Progress: 260/810 combinations tested...
# Progress: 270/810 combinations tested...
# Progress: 280/810 combinations tested...
# Progress: 290/810 combinations tested...
# Progress: 300/810 combinations tested...
# Progress: 310/810 combinations tested...
# Progress: 320/810 combinations tested...
# Progress: 330/810 combinations tested...
# Progress: 340/810 combinations tested...
# Progress: 350/810 combinations tested...
# Progress: 360/810 combinations tested...
# Progress: 370/810 combinations tested...
# Progress: 380/810 combinations tested...
# Progress: 390/810 combinations tested...
# Progress: 400/810 combinations tested...
# Progress: 410/810 combinations tested...
# Progress: 420/810 combinations tested...
# Progress: 430/810 combinations tested...
# Progress: 440/810 combinations tested...
# Progress: 450/810 combinations tested...
# Progress: 460/810 combinations tested...
# Progress: 470/810 combinations tested...
# Progress: 480/810 combinations tested...
# Progress: 490/810 combinations tested...
# Progress: 500/810 combinations tested...
# Progress: 510/810 combinations tested...
# Progress: 520/810 combinations tested...
# Progress: 530/810 combinations tested...
# Progress: 540/810 combinations tested...
# Progress: 550/810 combinations tested...
# Progress: 560/810 combinations tested...
# Progress: 570/810 combinations tested...
# Progress: 580/810 combinations tested...
# Progress: 590/810 combinations tested...
# Progress: 600/810 combinations tested...
# Progress: 610/810 combinations tested...
# Progress: 620/810 combinations tested...
# Progress: 630/810 combinations tested...
# Progress: 640/810 combinations tested...
#   New best score: 0.8366 with params: {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': 'balanced'}
# Progress: 650/810 combinations tested...
# Progress: 660/810 combinations tested...
# Progress: 670/810 combinations tested...
# Progress: 680/810 combinations tested...
# Progress: 690/810 combinations tested...
# Progress: 700/810 combinations tested...
# Progress: 710/810 combinations tested...
# Progress: 720/810 combinations tested...
# Progress: 730/810 combinations tested...
# Progress: 740/810 combinations tested...
# Progress: 750/810 combinations tested...
# Progress: 760/810 combinations tested...
# Progress: 770/810 combinations tested...
# Progress: 780/810 combinations tested...
#   New best score: 0.8374 with params: {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': 'balanced'}
# Progress: 790/810 combinations tested...
# Progress: 800/810 combinations tested...
# Progress: 810/810 combinations tested...
#
# ======================================================================
# Best Parameters:
#   n_estimators: 200
#   max_depth: None
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: sqrt
#   class_weight: balanced
# Best F1: 0.8374
# Best threshold: 0.4150
# ======================================================================
#
# Final Model Performance:
# F1 Score: 0.8374
# ROC-AUC Score: 0.9748
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      7029
#            1       0.86      0.81      0.84      1964
#
#     accuracy                           0.93      8993
#    macro avg       0.91      0.89      0.90      8993
# weighted avg       0.93      0.93      0.93      8993

# %%
X_test = random_forest_dv.transform(df_test.to_dict(orient='records'))
y_test_pred_proba = random_forest_model.predict_proba(X_test)[:, 1]
y_pred_final = (y_test_pred_proba >= random_forest_threshold).astype(int)

# %%
print(f"F1 Score: {f1_score(y_test, y_pred_final):.4f}")
print(f"ROC-AUC Score: {roc_auc_score(y_test, y_test_pred_proba):.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_final))
# Out:
# F1 Score: 0.8374
# ROC-AUC Score: 0.9748
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      7029
#            1       0.86      0.81      0.84      1964
#
#     accuracy                           0.93      8993
#    macro avg       0.91      0.89      0.90      8993
# weighted avg       0.93      0.93      0.93      8993

# %%
accuracy_score(y_test, y_pred_final)
# Out:
# 0.9310574891582342

# %%
import pickle

# %%
with open('midterm_model.bin', 'wb') as f_out:
    pickle.dump((random_forest_model, random_forest_dv, random_forest_threshold), f_out)

# %%
# !jupyter nbconvert --to script Midterm-project.ipynb
# Out:
# [NbConvertApp] Converting notebook Midterm-project.ipynb to script
# [NbConvertApp] Writing 27385 bytes to Midterm-project.py
